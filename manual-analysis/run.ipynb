# %% [markdown]
# # Design Pattern Analysis Chat
#
# Interactive notebook for analyzing design patterns in codebases.

# %% [markdown]
# ## Step 1: Configuration

# %%
import os

# Set model (optional - defaults to deepseek-coder-6.7b-instruct)
MODEL = "deepseek-ai/deepseek-coder-6.7b-instruct"
# MODEL = "microsoft/phi-2"  # Alternative: smaller, faster

os.environ['LLM_MODEL'] = MODEL

print(f"Model configured: {MODEL}")

# %% [markdown]
# ## Step 2: Clone or Update Repository

# %%
import os

REPO_URL = "https://github.com/josiasdeveloper/software-engineering.git"

if os.path.exists('software-engineering'):
    print("Repository exists, updating...")
    # %cd software-engineering/manual-analysis
    # !git pull
else:
    print("Cloning repository...")
    # !git clone {REPO_URL}
    # %cd software-engineering/manual-analysis

print("\nReady!")

# %% [markdown]
# ## Step 3: Install Dependencies

# %%
# !pip install -e . -q

# %% [markdown]
# ## Step 4: Run Interactive Chat
#
# Available commands in chat:
# - `/help` - Show help
# - `/clear` - Clear history
# - `/restart` - Restart model
# - `/save [path]` - Save conversation
# - `/context` - Show context info
# - `/exit` - Exit chat

# %%
# !chat
